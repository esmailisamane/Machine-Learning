# %% [markdown]
# <a href="https://colab.research.google.com/github/esmailisamane/Machine-Learning/blob/main/GrayScaleImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
im = np.arange(32)
im=im[np.newaxis, :]
im = np.repeat(im, 10, axis=0)
plt.imshow(im, cmap='gray')

# %%
im = np.arange(256)
im = im[np.newaxis, :]
im = np.repeat(im, 100, axis=0)
plt.imshow(im, cmap='gray')

# %%
# Procceing Grayscale images

# %%
im = plt.imread(r'/content/sample_data/Images/Albert_Einstein_Head.jpg')

# %%
type(im)
im.shape
# Out:
# (4333, 3250)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im, cmap='gray')

# %%
im
# Out:
# array([[64, 62, 59, ..., 28, 25, 25],
#        [59, 62, 63, ..., 25, 26, 26],
#        [58, 62, 66, ..., 24, 27, 27],
#        ...,
#        [17, 18, 19, ..., 64, 68, 76],
#        [17, 19, 19, ..., 70, 77, 85],
#        [17, 19, 20, ..., 76, 85, 93]], dtype=uint8)

# %%
im[23, 100]  #color code
# Out:
# 56

# %%
im2 = im.copy()

# %%
im2[23:2000, 40:2000] = 255
plt.imshow(im2, cmap='gray')

# %%
im2[2000:3000, 100:4000] = 0
plt.imshow(im2, cmap='gray')

# %%
plt.imsave(r'/content/sample_data/Images/Albert_Einstein_Head_modified.jpg', im2)
